# %% [markdown]
# ## Matplotlib
#   - python library for detailed graphs
#
# ### pyplot
#   - is a matplotlib module.
#   - Creates figure, labels, and plot area

# %%
import matplotlib.pyplot  as plt

# %% [markdown]
# ### plot()
#  - Draws points with default connecting lines
#  `syntax: plot(x axis, y axis)`
#
#  <p><strong>e.g. draw line in diagram</strong></p>

# %%
# Basic line graph using plot()
plt.plot([1,3,2], [2,4,2])

#show plot & hide default title
plt.show()

# %% [markdown]
# <p><strong>Default X points values 0,1,2,3....</strong></p>

# %%
import numpy as np

ypoints = np.array([2, 4, 1, 5])

#plotting without x-points
plt.figure()

plt.plot(ypoints) # y axis

plt.show()

# %% [markdown]
# ### Format Strings
# <p><strong>marker |line | color</strong></p>
#  - optional 3rd argument in plot() for
#  <strong>'marker, 'line type' and 'color'</strong>

# %% [markdown]
# ### Line Color Change
# 'color' or 'c' use shortcut string
# - <strong>ways to specify colors:-</strong>
#
#        Named COlors: 'red', 'green', 'blue'
#
#        Short Color codes: 'r' for red, 'g' for green, 'b' for blue
#
#        RGB & Hexadecimal Color Codes

# %%
plt.plot(ypoints, 'g')
plt.show()

# %% [markdown]
# ### Change Line Style
#  'linestyle' or use shortcut string
#  `eg: '--', '-','.', ',', 'o', 'v', '^', '<', '>', '+', '=', '|', '_', '*', ':' `

# %%
plt.plot(ypoints, 'o')
plt.show()

# %%
plt.plot(ypoints, '*')
plt.show()

# %% [markdown]
# ### Multple Lines
#   - Plot x and y axis seperately

# %%
x = [10,4,7,1]
y = [2,8,3,9]

plt.plot(x, marker = '^', color = 'g')
plt.plot(y, marker = 'D', color = 'r')

plt.show()

# %% [markdown]
# ### Marker
# - mark the data points on a line plot
# `styles available: 'o', 's', 'D', 'd', 'x', 'X', 'P', 'p', 'H', 'h', 'v', '1', '2', '3', '4', '^', '>', '<', '.', '*', ',', '|', '_', '-', '+'`

# %%
plt.plot(ypoints, marker = 'o', color = 'g')
plt.show()

# %% [markdown]
# ### Marker Size

# %% [markdown]
# argument `markersize` or rhe shorter version `ms`

# %%
plt.plot(ypoints, marker = '*', ms = 15)
plt.show()

# %% [markdown]
# ### Marker Color

# %% [markdown]
# `markeredgecolor` or `mec` to set the color of the edge `markerfacecolor` or `mfc` to set the color inside the edge

# %%
plt.plot(ypoints, marker = 'o', ms = 24, mec = 'r', mfc = 'g')
plt.show()

# %% [markdown]
# ### Marker + Line + Color

# %%
# marker = 'o', line =':' color green 'g'

plt.plot(ypoints, 'o:g')
plt.show()

# %% [markdown]
# ### Labels and Title
# xlabels() and ylabels() functions to set label for x and y-axis title() function to set a title

# %%
plt.title('Cen-Title')
plt.xlabel('Cen-x-axis')
plt.ylabel('Cen-y-axis')

plt.show()

# %% [markdown]
# ### Font of Title and Labels
# `fontdict` parameter

# %%
font1 = {'family': 'serif', 'size': 25, 'color': 'blue'}
font2 = {'family': 'serif', 'size':20, 'color': 'green'}

#'loc' to position the title 

plt.title('Cen-tech',fontdict= font1, loc='right')
plt.xlabel('Cen-x-axis',fontdict= font2)
plt.ylabel('Cen-y-axis',fontdict= font2)

plt.show()

# %% [markdown]
# ### Grid Lines

# %%
plt.grid()

# %% [markdown]
# grid lines for the x-axis

# %%
plt.grid(axis='x')

# %% [markdown]
# grid lines for the y-axis

# %%
plt.grid(axis='y')

# %% [markdown]
# Line Properties for the Grid

# %%
plt.grid(color ='green', linestyle ='--', linewidth =1.5)

# %% [markdown]
# ### Multiple Plots
# #### Method 1: Subplot
# - draw multiple plots in one figure
# - syntax: `subplot(rows, columns, index)`

# %% [markdown]
# Draw Two Plots: 1 row 2 columns

# %%
plt.subplot(1, 2, 1)  # 1st plot

plt.subplot(1, 2, 2) # 2nd plot

plt.show()

# %% [markdown]
# 2 row and 1 column

# %%
plt.subplot(2, 1, 1) # 1st plot
plt.subplot(2, 1, 2) # 2nd plot

plt.show()

# %% [markdown]
# 2 row and 2 column subplot

# %%
plt.subplot(2, 2, 1) # Subplot 1

plt.subplot(2, 2, 2) # Subplot 2

plt.subplot(2, 2, 3) # Subplot 3

plt.subplot(2, 2, 4) # Subplot 4

plt.show()

# %% [markdown]
# ##### Method 2: add_subplot
# Syntax:- `add_subplot(rows, cols, index)`
#
# ##### Figure and Axes
# - Figure represents entire area where your data visualization will be displayed
#     - like a container that holds all the individual plots or charts
# - Axes is like an individual plot or chart within the figure
#     - e.g. line charts, scatter plots, bar graphs

# %%
# add subplots to the figure
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

# %% [markdown]
# ##### Method 3: Subplots()

# %%
plt.subplots()

# it return 2 values in tuple
# (<figure with 1 Axes>, <Axes:>)

# %%
#  Unpack a tuple into fig and ax.
fig, ax = plt.subplots(1,2)

# 1 row 2 columns

# %% [markdown]
# ##### Create Mutliple Axes With Example

# %%
# creaate data
x = [0, 1, 2, 3]
y = [3, 8, 1, 10]

# %%
fig, ax = plt.subplots(1,2)

ax[0].plot(x, y)
ax[1].bar(x, y)

fig.suptitle('Figure of 2 Plot')

plt.show()

# %% [markdown]
# ##### Alternate code

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
ax1.plot(x, y)
ax2.bar(x, y)

fig.suptitle('fig, ax1 ax2')
plt.show()

# %% [markdown]
# #### Vertically stacked subplots

# %%
fig, ax = plt.subplots(2)
# row = 0, column = 2

ax[0].plot(x, y)
ax[1].bar(x, y)

fig.suptitle('Vertically stacked Plots')
plt.show()

# %% [markdown]
# 2 rows 2 columns

# %%
fig, ax = plt.subplots(2, 2)

ax[0, 0].plot(x, y)
ax[0, 1].plot(x, y, 'tab:orange')
ax[1, 0].plot(x, y, 'tab:green')
ax[1, 1].plot(x, y, 'tab:red')

plt.show()

# %% [markdown]
# ##### Alternate code

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2)

ax1.plot(x, y,)
ax2.plot(x, y, 'tab:orange')
ax3.plot(x, y, 'tab:green')
ax4.plot(x, y, 'tab:red')

plt.show()

# %% [markdown]
# #### legend()

# %%
plt.plot(x,y)
plt.plot(y,x)

plt.legend(['Dataset1', 'Dataset2'])

plt.show()

# %% [markdown]
# ### More Different Types of Plots

# %% [markdown]
# #### Bar Graph  - bar()

# %%
x = [1,2,3,4]
y = [5,6,7,8]

plt.bar(x,y)

plt.show()

# %% [markdown]
# #### Change color of bar

# %%
#set color of bar 
c = ['r', 'g', 'b', 'y']
plt.bar(x,y, color = c)

plt.show()

# %% [markdown]
# #### horizontal Bar graph   - barh()

# %%
plt.barh(x,y)

plt.show()

# %% [markdown]
# ####  change width and height of bar

# %%
# width use in vertical bar
plt.bar(x,y, width =0.3)
plt.show()

# %%
# height use in horizontal bar

plt.barh(x,y, height=0.2)
plt.show()

# %% [markdown]
# ### Scatter Plot  - scatter()

# %%
x = [1,2,3,4]
y = [5,6,7,8]

plt.scatter(x,y)
plt.show()

# %% [markdown]
# #### change size of scatter plot
# s parameter in scatter()

# %%
plt.scatter(x,y, s=200)

plt.show()

# %% [markdown]
# ### Pie Chart

# %%
x = [10,20,30,40] # create data
y = ['a', 'b', 'c','d'] # create labels


plt.pie(x, labels=y)
plt.show()

# %% [markdown]
# ### Histograms

# %%
plt.hist([1,2,2,3,4,4,5],bins=5)

# labelling ---(optional)
plt.title('cen-histogram')
plt.xlabel('cen-values')
plt.ylabel('cen-frequency')

plt.show()

# %% [markdown]
# ### 3D Plots

# %%
# creating the figure object

fig = plt.figure()

# creates the 3d plot
ax = plt.axes(projection = '3d')
plt.show()

# %% [markdown]
# ### 3D Line Plot

# %%
# creating data
x = [1,2,3,4,5]
y = [1,4,9,16,25]
z = [1,8,27,64,125]

# %%
fig = plt.figure()

#creates the 3d plot
ax = plt.axes(projection = '3d')
ax.plot3D(z, y, x)
plt.show()

# %% [markdown]
# #### Emmanuel Nsubuga 💫
